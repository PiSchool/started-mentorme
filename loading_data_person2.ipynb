# %% [markdown]
# ## Goal of this Notebook
# With this colab notebook we want to get you running as fast as possible. That means:
# 1. Loading and exploring the data
# 2. Running initial models
# ## Features of this Notebook
# 1. Easy to access the data
# 2. Has tesla t4 GPU which is a top tier GPU with 16gb memory
# 3. Has 500 gb local storage
# 4. It now supports a file system with a text editor (similar to jupyter lab)
# 5. Sadly, it only has 12 gb of system memory
# ## Connecting it to google drive:
# 1. Make sure you are working on the google account given to you by us: the @picampus-school.com account.
# 2. First, you need to add the proejct folder we shared with you to my drive.
# 3. then you can run the notebook below

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # New Section

# %%
import sys
from google.colab import drive
#remember to select your @picampus- school account here for mounting
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys,os
PROJECT_NAME="started-startups"

#changing directory to google colab directory #
#os.chdir(f"/content/drive/My Drive/{PROJECT_NAME}/{PROJECT_NAME}-github#")
os.chdir(f"/content/drive/My Drive/{PROJECT_NAME}/{PROJECT_NAME}-github")

#this is to be able to load the data from the shared stakeholder folder: Don't write 
#anything there. 
STAKEHOLDER_DATA_PATH=f"/content/drive/My Drive/{PROJECT_NAME}/shared_with_stakeholder/data/"
